# %%
import pandas as pd

# %%
file_path = 'data/PU_BaseTable.xlsx'
df = pd.read_excel(file_path)

selected_columns = [
    'Purchasing Document Number [EKKO_EBELN]', 'Item Number of Purchasing Document [EKPO_EBELP]', 'Company Code [EKKO_BUKRS]', 'Name of Company Code or Company [T001_BUTXT]', 'Currency Key [T001_WAERS]',
    'Document Category Description [DD07T_BSTYP_DDTEXT]', 'Purchasing Document Type [EKKO_BSART]', 'Short Description of Purchasing Document Type [T161T_BATXT]', 'Creation Date of Purchasing Document [EKKO_AEDAT]', 'Purchase Order Creator [c_EKKO_ERNAM]',
    'Purchase Order Creator Department [c_EKKO_ERNAM_DEPARTMENT]', 'Vendor\'s account number [EKKO_LIFNR]', 'Name 1 [LFA1_NAME1]', 'Vendor Creation Date [c_LFA1_ERDAT]', 'Description of purchasing group [T024_EKNAM]',
    'PO Approver [c_PO_Approver]', 'Short Text [EKPO_TXZ01]', 'Material Group Description [T023T_WGBEZ]', 'Net PO Value in Reporting Currency [c_EKPO_NETWR_RC]', 'Text for Item Category [T163Y_PTEXT]',
    'Invoice Receipt Value in Reporting Currency [c_EKBE_DMBTR_2_RC]', 'Invoice Receipt First Document Date [c_EKBE_BLDAT_First_2]', 'Invoice Receipt First Posting Date [c_EKBE_BUDAT_First_2]'
]

df_selected = df[selected_columns]

# df_selected
# df_selected[df_selected['Purchasing Document Number [EKKO_EBELN]'] == 4504581776]
# df_selected[df_selected['Purchasing Document Number [EKKO_EBELN]'] == 4504581777]

# %% [markdown]
# Pivot Table approach

# %%
# Create a pivot table to group by 'Purchasing Document Number [EKKO_EBELN]' and sum relevant columns
pivot_df = df_selected.pivot_table(
    index='Purchasing Document Number [EKKO_EBELN]',
    values=[
        'Net PO Value in Reporting Currency [c_EKPO_NETWR_RC]',
        'Invoice Receipt Value in Reporting Currency [c_EKBE_DMBTR_2_RC]'
    ],
    aggfunc='sum'
).reset_index()

# Merge the pivot table with the first occurrence of the remaining columns
first_occurrence_df = df_selected.drop_duplicates(subset='Purchasing Document Number [EKKO_EBELN]')

result_df = pd.merge(first_occurrence_df, pivot_df, on='Purchasing Document Number [EKKO_EBELN]', suffixes=('', '_summed'))

# Save the resulting dataframe to a new Excel file
# result_df.to_excel('data/PU_Pivot_GroupedTable.xlsx', index=False)

# %%
# Add new columns
result_df['Invoice Received'] = result_df['Invoice Receipt First Document Date [c_EKBE_BLDAT_First_2]'].notna()
result_df.head()
# Out:
#    Purchasing Document Number [EKKO_EBELN]  \
# 0                               4504533472
# 1                               4504581776
# 2                               4504581777
# 3                               4505858980
# 4                               4505986415
#
#    Item Number of Purchasing Document [EKPO_EBELP]  Company Code [EKKO_BUKRS]  \
# 0                                               10                       5211
# 1                                               10                       5211
# 2                                               30                       5211
# 3                                               10                       5211
# 4                                               10                       5211
#
#   Name of Company Code or Company [T001_BUTXT] Currency Key [T001_WAERS]  \
# 0                             Hiestand Germany                       EUR
# 1                             Hiestand Germany                       EUR
# 2                             Hiestand Germany                       EUR
# 3                             Hiestand Germany                       EUR
# 4                             Hiestand Germany                       EUR
#
#   Document Category Description [DD07T_BSTYP_DDTEXT]  \
# 0                                     Purchase Order
# 1                                     Purchase Order
# 2                                     Purchase Order
# 3                                     Purchase Order
# 4                                     Purchase Order
#
#   Purchasing Document Type [EKKO_BSART]  \
# 0                                   ZUD
# 1                                    NB
# 2                                    NB
# 3                                    NB
# 4                                    NB
#
#   Short Description of Purchasing Document Type [T161T_BATXT]  \
# 0                               ARYZTA StockTransDel
# 1                                        Standard PO
# 2                                        Standard PO
# 3                                        Standard PO
# 4                                        Standard PO
#
#   Creation Date of Purchasing Document [EKKO_AEDAT]  \
# 0                                        2024-05-21
# 1                                        2024-04-10
# 2                                        2024-04-29
# 3                                        2024-05-15
# 4                                        2024-04-02
#
#   Purchase Order Creator [c_EKKO_ERNAM]  ...  \
# 0                              RHOFMANN  ...
# 1                              EGNEBNER  ...
# 2                              GGEILING  ...
# 3                                CMICHL  ...
# 4                                CMICHL  ...
#
#                    Short Text [EKPO_TXZ01]  \
# 0               VP SI 85G CHNKY CHOC SUPRM
# 1  Baldor, Part.Nr. VEM3546 f. Oszillation
# 2                      TK Stiefel Cofra 43
# 3           SG1 White Confectionery Chunks
# 4      Choc Chunks .5 x.5 x.125 semi sweet
#
#   Material Group Description [T023T_WGBEZ]  \
# 0                                   Cookie
# 1                              Spare Parts
# 2                          Human Resources
# 3                     Cocoa/Choc-Chocolate
# 4                     Cocoa/Choc-Chocolate
#
#   Net PO Value in Reporting Currency [c_EKPO_NETWR_RC]  \
# 0                                               0.00
# 1                                             484.00
# 2                                              88.99
# 3                                           56100.00
# 4                                           16358.17
#
#   Text for Item Category [T163Y_PTEXT]  \
# 0                       Stock transfer
# 1                             Standard
# 2                             Standard
# 3                             Standard
# 4                             Standard
#
#   Invoice Receipt Value in Reporting Currency [c_EKBE_DMBTR_2_RC]  \
# 0                                                NaN
# 1                                             484.00
# 2                                              88.99
# 3                                           56100.00
# 4                                           16358.17
#
#   Invoice Receipt First Document Date [c_EKBE_BLDAT_First_2]  \
# 0                                                NaN
# 1                                         2024-04-24
# 2                                         2024-04-30
# 3                                         2024-06-18
# 4                                         2024-04-16
#
#   Invoice Receipt First Posting Date [c_EKBE_BUDAT_First_2]  \
# 0                                                NaN
# 1                                         2024-05-14
# 2                                         2024-05-03
# 3                                         2024-06-19
# 4                                         2024-04-17
#
#   Invoice Receipt Value in Reporting Currency [c_EKBE_DMBTR_2_RC]_summed  \
# 0                                               0.00
# 1                                             554.18
# 2                                             219.10
# 3                                           56100.00
# 4                                           16358.17
#
#    Net PO Value in Reporting Currency [c_EKPO_NETWR_RC]_summed  \
# 0                                               0.00
# 1                                             554.18
# 2                                             220.06
# 3                                           56100.00
# 4                                           16358.17
#
#   Invoice Received
# 0            False
# 1             True
# 2             True
# 3             True
# 4             True
#
# [5 rows x 26 columns]

# %%
def determine_po_after_invoice(row):
    if not row['Invoice Received']:
        return 'N/A'
    elif pd.to_datetime(row['Creation Date of Purchasing Document [EKKO_AEDAT]']) > pd.to_datetime(row['Invoice Receipt First Document Date [c_EKBE_BLDAT_First_2]']):
        return True
    else:
        return False

result_df['PO After Invoice'] = result_df.apply(determine_po_after_invoice, axis=1)

result_df.head(10)
# Out:
#    Purchasing Document Number [EKKO_EBELN]  \
# 0                               4504533472
# 1                               4504581776
# 2                               4504581777
# 3                               4505858980
# 4                               4505986415
#
#    Item Number of Purchasing Document [EKPO_EBELP]  Company Code [EKKO_BUKRS]  \
# 0                                               10                       5211
# 1                                               10                       5211
# 2                                               30                       5211
# 3                                               10                       5211
# 4                                               10                       5211
#
#   Name of Company Code or Company [T001_BUTXT] Currency Key [T001_WAERS]  \
# 0                             Hiestand Germany                       EUR
# 1                             Hiestand Germany                       EUR
# 2                             Hiestand Germany                       EUR
# 3                             Hiestand Germany                       EUR
# 4                             Hiestand Germany                       EUR
#
#   Document Category Description [DD07T_BSTYP_DDTEXT]  \
# 0                                     Purchase Order
# 1                                     Purchase Order
# 2                                     Purchase Order
# 3                                     Purchase Order
# 4                                     Purchase Order
#
#   Purchasing Document Type [EKKO_BSART]  \
# 0                                   ZUD
# 1                                    NB
# 2                                    NB
# 3                                    NB
# 4                                    NB
#
#   Short Description of Purchasing Document Type [T161T_BATXT]  \
# 0                               ARYZTA StockTransDel
# 1                                        Standard PO
# 2                                        Standard PO
# 3                                        Standard PO
# 4                                        Standard PO
#
#   Creation Date of Purchasing Document [EKKO_AEDAT]  \
# 0                                        2024-05-21
# 1                                        2024-04-10
# 2                                        2024-04-29
# 3                                        2024-05-15
# 4                                        2024-04-02
#
#   Purchase Order Creator [c_EKKO_ERNAM]  ...  \
# 0                              RHOFMANN  ...
# 1                              EGNEBNER  ...
# 2                              GGEILING  ...
# 3                                CMICHL  ...
# 4                                CMICHL  ...
#
#   Material Group Description [T023T_WGBEZ]  \
# 0                                   Cookie
# 1                              Spare Parts
# 2                          Human Resources
# 3                     Cocoa/Choc-Chocolate
# 4                     Cocoa/Choc-Chocolate
#
#   Net PO Value in Reporting Currency [c_EKPO_NETWR_RC]  \
# 0                                               0.00
# 1                                             484.00
# 2                                              88.99
# 3                                           56100.00
# 4                                           16358.17
#
#   Text for Item Category [T163Y_PTEXT]  \
# 0                       Stock transfer
# 1                             Standard
# 2                             Standard
# 3                             Standard
# 4                             Standard
#
#   Invoice Receipt Value in Reporting Currency [c_EKBE_DMBTR_2_RC]  \
# 0                                                NaN
# 1                                             484.00
# 2                                              88.99
# 3                                           56100.00
# 4                                           16358.17
#
#   Invoice Receipt First Document Date [c_EKBE_BLDAT_First_2]  \
# 0                                                NaN
# 1                                         2024-04-24
# 2                                         2024-04-30
# 3                                         2024-06-18
# 4                                         2024-04-16
#
#   Invoice Receipt First Posting Date [c_EKBE_BUDAT_First_2]  \
# 0                                                NaN
# 1                                         2024-05-14
# 2                                         2024-05-03
# 3                                         2024-06-19
# 4                                         2024-04-17
#
#   Invoice Receipt Value in Reporting Currency [c_EKBE_DMBTR_2_RC]_summed  \
# 0                                               0.00
# 1                                             554.18
# 2                                             219.10
# 3                                           56100.00
# 4                                           16358.17
#
#   Net PO Value in Reporting Currency [c_EKPO_NETWR_RC]_summed  \
# 0                                               0.00
# 1                                             554.18
# 2                                             220.06
# 3                                           56100.00
# 4                                           16358.17
#
#    Invoice Received PO After Invoice
# 0             False              N/A
# 1              True            False
# 2              True            False
# 3              True            False
# 4              True            False
#
# [5 rows x 27 columns]

# %%
result_df['Vendor Created'] = result_df['Vendor Creation Date [c_LFA1_ERDAT]'].notna()
result_df.head(10)
# Out:
#    Purchasing Document Number [EKKO_EBELN]  \
# 0                               4504533472
# 1                               4504581776
# 2                               4504581777
# 3                               4505858980
# 4                               4505986415
# 5                               4506004561
# 6                               4506016458
# 7                               4506016462
# 8                               4506123657
# 9                               4506135651
#
#    Item Number of Purchasing Document [EKPO_EBELP]  Company Code [EKKO_BUKRS]  \
# 0                                               10                       5211
# 1                                               10                       5211
# 2                                               30                       5211
# 3                                               10                       5211
# 4                                               10                       5211
# 5                                               10                       5211
# 6                                               10                       5211
# 7                                               10                       5211
# 8                                               10                       5211
# 9                                               10                       5211
#
#   Name of Company Code or Company [T001_BUTXT] Currency Key [T001_WAERS]  \
# 0                             Hiestand Germany                       EUR
# 1                             Hiestand Germany                       EUR
# 2                             Hiestand Germany                       EUR
# 3                             Hiestand Germany                       EUR
# 4                             Hiestand Germany                       EUR
# 5                             Hiestand Germany                       EUR
# 6                             Hiestand Germany                       EUR
# 7                             Hiestand Germany                       EUR
# 8                             Hiestand Germany                       EUR
# 9                             Hiestand Germany                       EUR
#
#   Document Category Description [DD07T_BSTYP_DDTEXT]  \
# 0                                     Purchase Order
# 1                                     Purchase Order
# 2                                     Purchase Order
# 3                                     Purchase Order
# 4                                     Purchase Order
# 5                                     Purchase Order
# 6                                     Purchase Order
# 7                                     Purchase Order
# 8                                     Purchase Order
# 9                                     Purchase Order
#
#   Purchasing Document Type [EKKO_BSART]  \
# 0                                   ZUD
# 1                                    NB
# 2                                    NB
# 3                                    NB
# 4                                    NB
# 5                                   ZUD
# 6                                    NB
# 7                                    NB
# 8                                    NB
# 9                                    NB
#
#   Short Description of Purchasing Document Type [T161T_BATXT]  \
# 0                               ARYZTA StockTransDel
# 1                                        Standard PO
# 2                                        Standard PO
# 3                                        Standard PO
# 4                                        Standard PO
# 5                               ARYZTA StockTransDel
# 6                                        Standard PO
# 7                                        Standard PO
# 8                                        Standard PO
# 9                                        Standard PO
#
#   Creation Date of Purchasing Document [EKKO_AEDAT]  \
# 0                                        2024-05-21
# 1                                        2024-04-10
# 2                                        2024-04-29
# 3                                        2024-05-15
# 4                                        2024-04-02
# 5                                        2024-01-05
# 6                                        2024-02-07
# 7                                        2024-02-09
# 8                                        2024-01-26
# 9                                        2024-01-26
#
#   Purchase Order Creator [c_EKKO_ERNAM]  ...  \
# 0                              RHOFMANN  ...
# 1                              EGNEBNER  ...
# 2                              GGEILING  ...
# 3                                CMICHL  ...
# 4                                CMICHL  ...
# 5                              RHOFMANN  ...
# 6                              GGEILING  ...
# 7                              GGEILING  ...
# 8                               SKRAUSS  ...
# 9                               SKRAUSS  ...
#
#   Net PO Value in Reporting Currency [c_EKPO_NETWR_RC]  \
# 0                                               0.00
# 1                                             484.00
# 2                                              88.99
# 3                                           56100.00
# 4                                           16358.17
# 5                                               0.00
# 6                                              34.65
# 7                                            1209.00
# 8                                           11325.00
# 9                                            3292.21
#
#   Text for Item Category [T163Y_PTEXT]  \
# 0                       Stock transfer
# 1                             Standard
# 2                             Standard
# 3                             Standard
# 4                             Standard
# 5                       Stock transfer
# 6                             Standard
# 7                             Standard
# 8                             Standard
# 9                             Standard
#
#   Invoice Receipt Value in Reporting Currency [c_EKBE_DMBTR_2_RC]  \
# 0                                                NaN
# 1                                             484.00
# 2                                              88.99
# 3                                           56100.00
# 4                                           16358.17
# 5                                                NaN
# 6                                                NaN
# 7                                            1209.00
# 8                                           11230.62
# 9                                            3292.14
#
#   Invoice Receipt First Document Date [c_EKBE_BLDAT_First_2]  \
# 0                                                NaN
# 1                                         2024-04-24
# 2                                         2024-04-30
# 3                                         2024-06-18
# 4                                         2024-04-16
# 5                                                NaN
# 6                                                NaN
# 7                                         2024-02-10
# 8                                         2024-02-21
# 9                                         2024-02-29
#
#   Invoice Receipt First Posting Date [c_EKBE_BUDAT_First_2]  \
# 0                                                NaN
# 1                                         2024-05-14
# 2                                         2024-05-03
# 3                                         2024-06-19
# 4                                         2024-04-17
# 5                                                NaN
# 6                                                NaN
# 7                                         2024-02-16
# 8                                         2024-02-22
# 9                                         2024-03-01
#
#   Invoice Receipt Value in Reporting Currency [c_EKBE_DMBTR_2_RC]_summed  \
# 0                                               0.00
# 1                                             554.18
# 2                                             219.10
# 3                                           56100.00
# 4                                           16358.17
# 5                                               0.00
# 6                                               0.00
# 7                                            1209.00
# 8                                           11230.62
# 9                                            3292.14
#
#   Net PO Value in Reporting Currency [c_EKPO_NETWR_RC]_summed  \
# 0                                               0.00
# 1                                             554.18
# 2                                             220.06
# 3                                           56100.00
# 4                                           16358.17
# 5                                               0.00
# 6                                              50.45
# 7                                            1209.00
# 8                                           11419.38
# 9                                            3292.21
#
#   Invoice Received  PO After Invoice Vendor Created
# 0            False               N/A          False
# 1             True             False           True
# 2             True             False           True
# 3             True             False           True
# 4             True             False           True
# 5            False               N/A          False
# 6            False               N/A           True
# 7             True             False           True
# 8             True             False           True
# 9             True             False           True
#
# [10 rows x 28 columns]

# %%
# Add new column 'Vendor after PO (days)'
def calculate_vendor_after_po_days(row):
    if pd.notna(row['Vendor Creation Date [c_LFA1_ERDAT]']) and pd.to_datetime(row['Vendor Creation Date [c_LFA1_ERDAT]']) > pd.to_datetime(row['Creation Date of Purchasing Document [EKKO_AEDAT]']):
        return (pd.to_datetime(row['Vendor Creation Date [c_LFA1_ERDAT]']) - pd.to_datetime(row['Creation Date of Purchasing Document [EKKO_AEDAT]'])).days
    else:
        return 'N/A'

result_df['Vendor after PO (days)'] = result_df.apply(calculate_vendor_after_po_days, axis=1)

result_df.head(10)
# Out:
#    Purchasing Document Number [EKKO_EBELN]  \
# 0                               4504533472
# 1                               4504581776
# 2                               4504581777
# 3                               4505858980
# 4                               4505986415
# 5                               4506004561
# 6                               4506016458
# 7                               4506016462
# 8                               4506123657
# 9                               4506135651
#
#    Item Number of Purchasing Document [EKPO_EBELP]  Company Code [EKKO_BUKRS]  \
# 0                                               10                       5211
# 1                                               10                       5211
# 2                                               30                       5211
# 3                                               10                       5211
# 4                                               10                       5211
# 5                                               10                       5211
# 6                                               10                       5211
# 7                                               10                       5211
# 8                                               10                       5211
# 9                                               10                       5211
#
#   Name of Company Code or Company [T001_BUTXT] Currency Key [T001_WAERS]  \
# 0                             Hiestand Germany                       EUR
# 1                             Hiestand Germany                       EUR
# 2                             Hiestand Germany                       EUR
# 3                             Hiestand Germany                       EUR
# 4                             Hiestand Germany                       EUR
# 5                             Hiestand Germany                       EUR
# 6                             Hiestand Germany                       EUR
# 7                             Hiestand Germany                       EUR
# 8                             Hiestand Germany                       EUR
# 9                             Hiestand Germany                       EUR
#
#   Document Category Description [DD07T_BSTYP_DDTEXT]  \
# 0                                     Purchase Order
# 1                                     Purchase Order
# 2                                     Purchase Order
# 3                                     Purchase Order
# 4                                     Purchase Order
# 5                                     Purchase Order
# 6                                     Purchase Order
# 7                                     Purchase Order
# 8                                     Purchase Order
# 9                                     Purchase Order
#
#   Purchasing Document Type [EKKO_BSART]  \
# 0                                   ZUD
# 1                                    NB
# 2                                    NB
# 3                                    NB
# 4                                    NB
# 5                                   ZUD
# 6                                    NB
# 7                                    NB
# 8                                    NB
# 9                                    NB
#
#   Short Description of Purchasing Document Type [T161T_BATXT]  \
# 0                               ARYZTA StockTransDel
# 1                                        Standard PO
# 2                                        Standard PO
# 3                                        Standard PO
# 4                                        Standard PO
# 5                               ARYZTA StockTransDel
# 6                                        Standard PO
# 7                                        Standard PO
# 8                                        Standard PO
# 9                                        Standard PO
#
#   Creation Date of Purchasing Document [EKKO_AEDAT]  \
# 0                                        2024-05-21
# 1                                        2024-04-10
# 2                                        2024-04-29
# 3                                        2024-05-15
# 4                                        2024-04-02
# 5                                        2024-01-05
# 6                                        2024-02-07
# 7                                        2024-02-09
# 8                                        2024-01-26
# 9                                        2024-01-26
#
#   Purchase Order Creator [c_EKKO_ERNAM]  ...  \
# 0                              RHOFMANN  ...
# 1                              EGNEBNER  ...
# 2                              GGEILING  ...
# 3                                CMICHL  ...
# 4                                CMICHL  ...
# 5                              RHOFMANN  ...
# 6                              GGEILING  ...
# 7                              GGEILING  ...
# 8                               SKRAUSS  ...
# 9                               SKRAUSS  ...
#
#   Text for Item Category [T163Y_PTEXT]  \
# 0                       Stock transfer
# 1                             Standard
# 2                             Standard
# 3                             Standard
# 4                             Standard
# 5                       Stock transfer
# 6                             Standard
# 7                             Standard
# 8                             Standard
# 9                             Standard
#
#   Invoice Receipt Value in Reporting Currency [c_EKBE_DMBTR_2_RC]  \
# 0                                                NaN
# 1                                             484.00
# 2                                              88.99
# 3                                           56100.00
# 4                                           16358.17
# 5                                                NaN
# 6                                                NaN
# 7                                            1209.00
# 8                                           11230.62
# 9                                            3292.14
#
#   Invoice Receipt First Document Date [c_EKBE_BLDAT_First_2]  \
# 0                                                NaN
# 1                                         2024-04-24
# 2                                         2024-04-30
# 3                                         2024-06-18
# 4                                         2024-04-16
# 5                                                NaN
# 6                                                NaN
# 7                                         2024-02-10
# 8                                         2024-02-21
# 9                                         2024-02-29
#
#   Invoice Receipt First Posting Date [c_EKBE_BUDAT_First_2]  \
# 0                                                NaN
# 1                                         2024-05-14
# 2                                         2024-05-03
# 3                                         2024-06-19
# 4                                         2024-04-17
# 5                                                NaN
# 6                                                NaN
# 7                                         2024-02-16
# 8                                         2024-02-22
# 9                                         2024-03-01
#
#   Invoice Receipt Value in Reporting Currency [c_EKBE_DMBTR_2_RC]_summed  \
# 0                                               0.00
# 1                                             554.18
# 2                                             219.10
# 3                                           56100.00
# 4                                           16358.17
# 5                                               0.00
# 6                                               0.00
# 7                                            1209.00
# 8                                           11230.62
# 9                                            3292.14
#
#   Net PO Value in Reporting Currency [c_EKPO_NETWR_RC]_summed  \
# 0                                               0.00
# 1                                             554.18
# 2                                             220.06
# 3                                           56100.00
# 4                                           16358.17
# 5                                               0.00
# 6                                              50.45
# 7                                            1209.00
# 8                                           11419.38
# 9                                            3292.21
#
#   Invoice Received PO After Invoice  Vendor Created Vendor after PO (days)
# 0            False              N/A           False                    N/A
# 1             True            False            True                    N/A
# 2             True            False            True                    N/A
# 3             True            False            True                    N/A
# 4             True            False            True                    N/A
# 5            False              N/A           False                    N/A
# 6            False              N/A            True                    N/A
# 7             True            False            True                    N/A
# 8             True            False            True                    N/A
# 9             True            False            True                    N/A
#
# [10 rows x 29 columns]

# %%
# Add new column 'PO after Invoice (days)'
def calculate_po_after_invoice_days(row):
    if pd.notna(row['Invoice Receipt First Document Date [c_EKBE_BLDAT_First_2]']) and pd.to_datetime(row['Creation Date of Purchasing Document [EKKO_AEDAT]']) > pd.to_datetime(row['Invoice Receipt First Document Date [c_EKBE_BLDAT_First_2]']):
        return (pd.to_datetime(row['Creation Date of Purchasing Document [EKKO_AEDAT]']) - pd.to_datetime(row['Invoice Receipt First Document Date [c_EKBE_BLDAT_First_2]'])).days
    else:
        return 'N/A'

result_df['PO after Invoice (days)'] = result_df.apply(calculate_po_after_invoice_days, axis=1)

# Save the resulting dataframe to a new Excel file
result_df.to_excel('data/PU_GroupedTable.xlsx', index=False)

result_df.head(10)
# Out:
#    Purchasing Document Number [EKKO_EBELN]  \
# 0                               4504533472
# 1                               4504581776
# 2                               4504581777
# 3                               4505858980
# 4                               4505986415
# 5                               4506004561
# 6                               4506016458
# 7                               4506016462
# 8                               4506123657
# 9                               4506135651
#
#    Item Number of Purchasing Document [EKPO_EBELP]  Company Code [EKKO_BUKRS]  \
# 0                                               10                       5211
# 1                                               10                       5211
# 2                                               30                       5211
# 3                                               10                       5211
# 4                                               10                       5211
# 5                                               10                       5211
# 6                                               10                       5211
# 7                                               10                       5211
# 8                                               10                       5211
# 9                                               10                       5211
#
#   Name of Company Code or Company [T001_BUTXT] Currency Key [T001_WAERS]  \
# 0                             Hiestand Germany                       EUR
# 1                             Hiestand Germany                       EUR
# 2                             Hiestand Germany                       EUR
# 3                             Hiestand Germany                       EUR
# 4                             Hiestand Germany                       EUR
# 5                             Hiestand Germany                       EUR
# 6                             Hiestand Germany                       EUR
# 7                             Hiestand Germany                       EUR
# 8                             Hiestand Germany                       EUR
# 9                             Hiestand Germany                       EUR
#
#   Document Category Description [DD07T_BSTYP_DDTEXT]  \
# 0                                     Purchase Order
# 1                                     Purchase Order
# 2                                     Purchase Order
# 3                                     Purchase Order
# 4                                     Purchase Order
# 5                                     Purchase Order
# 6                                     Purchase Order
# 7                                     Purchase Order
# 8                                     Purchase Order
# 9                                     Purchase Order
#
#   Purchasing Document Type [EKKO_BSART]  \
# 0                                   ZUD
# 1                                    NB
# 2                                    NB
# 3                                    NB
# 4                                    NB
# 5                                   ZUD
# 6                                    NB
# 7                                    NB
# 8                                    NB
# 9                                    NB
#
#   Short Description of Purchasing Document Type [T161T_BATXT]  \
# 0                               ARYZTA StockTransDel
# 1                                        Standard PO
# 2                                        Standard PO
# 3                                        Standard PO
# 4                                        Standard PO
# 5                               ARYZTA StockTransDel
# 6                                        Standard PO
# 7                                        Standard PO
# 8                                        Standard PO
# 9                                        Standard PO
#
#   Creation Date of Purchasing Document [EKKO_AEDAT]  \
# 0                                        2024-05-21
# 1                                        2024-04-10
# 2                                        2024-04-29
# 3                                        2024-05-15
# 4                                        2024-04-02
# 5                                        2024-01-05
# 6                                        2024-02-07
# 7                                        2024-02-09
# 8                                        2024-01-26
# 9                                        2024-01-26
#
#   Purchase Order Creator [c_EKKO_ERNAM]  ...  \
# 0                              RHOFMANN  ...
# 1                              EGNEBNER  ...
# 2                              GGEILING  ...
# 3                                CMICHL  ...
# 4                                CMICHL  ...
# 5                              RHOFMANN  ...
# 6                              GGEILING  ...
# 7                              GGEILING  ...
# 8                               SKRAUSS  ...
# 9                               SKRAUSS  ...
#
#   Invoice Receipt Value in Reporting Currency [c_EKBE_DMBTR_2_RC]  \
# 0                                                NaN
# 1                                             484.00
# 2                                              88.99
# 3                                           56100.00
# 4                                           16358.17
# 5                                                NaN
# 6                                                NaN
# 7                                            1209.00
# 8                                           11230.62
# 9                                            3292.14
#
#   Invoice Receipt First Document Date [c_EKBE_BLDAT_First_2]  \
# 0                                                NaN
# 1                                         2024-04-24
# 2                                         2024-04-30
# 3                                         2024-06-18
# 4                                         2024-04-16
# 5                                                NaN
# 6                                                NaN
# 7                                         2024-02-10
# 8                                         2024-02-21
# 9                                         2024-02-29
#
#   Invoice Receipt First Posting Date [c_EKBE_BUDAT_First_2]  \
# 0                                                NaN
# 1                                         2024-05-14
# 2                                         2024-05-03
# 3                                         2024-06-19
# 4                                         2024-04-17
# 5                                                NaN
# 6                                                NaN
# 7                                         2024-02-16
# 8                                         2024-02-22
# 9                                         2024-03-01
#
#   Invoice Receipt Value in Reporting Currency [c_EKBE_DMBTR_2_RC]_summed  \
# 0                                               0.00
# 1                                             554.18
# 2                                             219.10
# 3                                           56100.00
# 4                                           16358.17
# 5                                               0.00
# 6                                               0.00
# 7                                            1209.00
# 8                                           11230.62
# 9                                            3292.14
#
#   Net PO Value in Reporting Currency [c_EKPO_NETWR_RC]_summed  \
# 0                                               0.00
# 1                                             554.18
# 2                                             220.06
# 3                                           56100.00
# 4                                           16358.17
# 5                                               0.00
# 6                                              50.45
# 7                                            1209.00
# 8                                           11419.38
# 9                                            3292.21
#
#   Invoice Received PO After Invoice Vendor Created  Vendor after PO (days)  \
# 0            False              N/A          False                     N/A
# 1             True            False           True                     N/A
# 2             True            False           True                     N/A
# 3             True            False           True                     N/A
# 4             True            False           True                     N/A
# 5            False              N/A          False                     N/A
# 6            False              N/A           True                     N/A
# 7             True            False           True                     N/A
# 8             True            False           True                     N/A
# 9             True            False           True                     N/A
#
#   PO after Invoice (days)
# 0                     N/A
# 1                     N/A
# 2                     N/A
# 3                     N/A
# 4                     N/A
# 5                     N/A
# 6                     N/A
# 7                     N/A
# 8                     N/A
# 9                     N/A
#
# [10 rows x 30 columns]
